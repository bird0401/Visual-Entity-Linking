# %%
# !mkdir data
bucket_name = "entity_dogs"
# !gsutil -m cp -r gs://{bucket_name}/imgs data
# Out:
# Copying gs://entity_dogs/imgs/Q10345998/image_0005.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0006.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0000.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0001.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0007.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0010.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0002.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0004.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0003.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0011.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0018.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0008.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0019.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0015.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0012.jpg...
# Copying gs://entity_dogs/imgs/Q10345998/image_0016.jpg...
# ...

# %%
# !df -h
